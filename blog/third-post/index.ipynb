# %% [markdown]
# ---
# title: Third Blog Post
# description: An example post where the source document is a Jupyter Notebook
# author: "Alicia"
# date: "5/24/2021"
# categories:
#   - Science
#   - Data
# ---

# %% [markdown]
# The source for any page in your website could also be a Jupyter Notebook. This one is `third-post/index.ipynb`.

# %% [markdown]
# Here's an example I borrowed from the [Seaborn docs](https://seaborn.pydata.org/examples/multiple_conditional_kde.html):

# %%
import seaborn as sns

sns.set_theme(style="whitegrid")

# Load the diamonds dataset
diamonds = sns.load_dataset("diamonds")

# Plot the distribution of clarity ratings, conditional on carat
sns.displot(
    data=diamonds,
    x="carat", hue="cut",
    kind="kde", height=4, aspect=1.5,
    multiple="fill", clip=(0, None),
    palette="ch:rot=-.25,hue=1,light=.75",   
)
